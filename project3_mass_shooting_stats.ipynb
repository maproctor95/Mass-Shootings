# %%
import pandas as pd

# %%
path = 'data/mass_shooting_events_stanford_msa_release_06142016.csv'
mass_shooting = pd.read_csv(path)

# %%
mass_shooting
# Out:
#      CaseID                           Title                Location  \
# 0       1.0   University of Texas at Austin           Austin, Texas
# 1       2.0      Rose-Mar College of Beauty           Mesa, Arizona
# 2       3.0    New Orleans Police Shootings  New Orleans, Louisiana
# 3       4.0  Clara Barton Elementary School       Chicago, Illinois
# 4       5.0               Olean High School         Olean, New York
# ..      ...                             ...                     ...
# 342     NaN                             NaN                     NaN
# 343     NaN                             NaN                     NaN
# 344     NaN                             NaN                     NaN
# 345     NaN                             NaN                     NaN
# 346     NaN                             NaN                     NaN
#
#             City      State   Latitude   Longitude  \
# 0         Austin      Texas  30.198887  -97.844159
# ...

# %%
mass_shooting.columns
# Out:
# Index(['CaseID', 'Title', 'Location', 'City', 'State', 'Latitude', 'Longitude',
#        'Number of Victim Fatalities', 'Total Number of Fatalities',
#        'Number of Victims Injured', 'Total Number of Victims', 'Description',
#        'Date', 'Day of Week', 'Date - Detailed', 'Shooter Name',
#        'Shooter Age(s)', 'Average Shooter Age', 'Shooter Sex', 'Shooter Race',
#        'Type of Gun - Detailed', 'Type of Gun - General', 'Number of Shotguns',
#        'Number of Rifles', 'Number of Handguns', 'Total Number of Guns',
#        'Number of Automatic Guns', 'Number of Semi-Automatic Guns',
#        'Fate of Shooter at the scene', 'Shooter's Cause of Death',
#        'School Related', 'Place Type', 'Relationship to Incident Location',
#        'Targeted Victim/s - Detailed', 'Targeted Victim/s - General',
#        'Possible Motive - Detailed', 'Possible Motive - General',
#        'History of Mental Illness - Detailed',
# ...

# %%
mass_shooting_revised = mass_shooting.drop(['Title', 'Location', 'Total Number of Fatalities',
    'Description',
    'Day of Week', 'Date - Detailed', 'Shooter Name',
       'Average Shooter Age',
       'Type of Gun - Detailed', 'Number of Shotguns',
       'Number of Rifles', 'Number of Handguns',
       'Number of Automatic Guns', 'Number of Semi-Automatic Guns',
       'Fate of Shooter at the scene',
       'School Related',
       'Targeted Victim/s - Detailed',
       'Possible Motive - Detailed',
       'History of Mental Illness - Detailed',
       'Data Source 1', 'Data Source 2',
       'Data Source 3', 'Data Source 4', 'Data Source 5', 'Data Source 6',
       'Data Source 7', 'Class'], axis = 1)

# %%
mass_shooting_revised
# Out:
#      CaseID         City      State   Latitude   Longitude  \
# 0       1.0       Austin      Texas  30.198887  -97.844159
# 1       2.0         Mesa    Arizona  33.422687 -111.816320
# 2       3.0  New Orleans  Louisiana  30.068724  -89.931474
# 3       4.0      Chicago   Illinois  41.839280  -87.688181
# 4       5.0        Olean   New York  42.081854  -78.432139
# ..      ...          ...        ...        ...         ...
# 342     NaN          NaN        NaN        NaN         NaN
# 343     NaN          NaN        NaN        NaN         NaN
# 344     NaN          NaN        NaN        NaN         NaN
# 345     NaN          NaN        NaN        NaN         NaN
# 346     NaN          NaN        NaN        NaN         NaN
#
#      Number of Victim Fatalities  Number of Victims Injured  \
# 0                           16.0                       32.0
# 1                            5.0                        1.0
# 2                            9.0                       13.0
# ...

# %%
mass_shooting_refined = mass_shooting_revised[['CaseID','City', 'State', 'Latitude', 'Longitude',
       'Number of Victim Fatalities',
       'Number of Victims Injured', 'Total Number of Victims',
       'Date',
       'Shooter Age(s)', 'Shooter Sex', 'Shooter Race',
       'Type of Gun - General','Total Number of Guns',"Shooter's Cause of Death",
       'Place Type', 'Relationship to Incident Location',
       'Targeted Victim/s - General','Possible Motive - General',
       'History of Mental Illness - General', 'Military Experience']]

# %%
mass_shooting_refined
# Out:
#      CaseID         City      State   Latitude   Longitude  \
# 0       1.0       Austin      Texas  30.198887  -97.844159
# 1       2.0         Mesa    Arizona  33.422687 -111.816320
# 2       3.0  New Orleans  Louisiana  30.068724  -89.931474
# 3       4.0      Chicago   Illinois  41.839280  -87.688181
# 4       5.0        Olean   New York  42.081854  -78.432139
# ..      ...          ...        ...        ...         ...
# 342     NaN          NaN        NaN        NaN         NaN
# 343     NaN          NaN        NaN        NaN         NaN
# 344     NaN          NaN        NaN        NaN         NaN
# 345     NaN          NaN        NaN        NaN         NaN
# 346     NaN          NaN        NaN        NaN         NaN
#
#      Number of Victim Fatalities  Number of Victims Injured  \
# 0                           16.0                       32.0
# 1                            5.0                        1.0
# 2                            9.0                       13.0
# ...

# %%
clean_df = mass_shooting_refined.dropna(how='all')

# %%
clean_df
# Out:
#      CaseID         City      State   Latitude   Longitude  \
# 0       1.0       Austin      Texas  30.198887  -97.844159
# 1       2.0         Mesa    Arizona  33.422687 -111.816320
# 2       3.0  New Orleans  Louisiana  30.068724  -89.931474
# 3       4.0      Chicago   Illinois  41.839280  -87.688181
# 4       5.0        Olean   New York  42.081854  -78.432139
# ..      ...          ...        ...        ...         ...
# 302   312.0  Brooksville    Alabama  34.162040  -86.475543
# 303   313.0    Baltimore   Maryland  39.290385  -76.612189
# 304   314.0      Halifax   Virginia  36.765971  -78.928344
# 305   315.0  Forestville   Maryland  38.845113  -76.874972
# 306   316.0     Ferguson   Missouri  38.744217  -90.305391
#
#      Number of Victim Fatalities  Number of Victims Injured  \
# 0                           16.0                       32.0
# 1                            5.0                        1.0
# 2                            9.0                       13.0
# ...

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307 entries, 0 to 306
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   CaseID                               307 non-null    float64
#  1   City                                 307 non-null    object
#  2   State                                307 non-null    object
#  3   Latitude                             307 non-null    float64
#  4   Longitude                            307 non-null    float64
#  5   Number of Victim Fatalities          307 non-null    float64
#  6   Number of Victims Injured            307 non-null    float64
#  7   Total Number of Victims              307 non-null    float64
#  8   Date                                 307 non-null    object
#  9   Shooter Age(s)                       307 non-null    object
#  10  Shooter Sex                          307 non-null    object
# ...

# %%
# clean_df['Shooter Age(s)'] = clean_df['Shooter Age(s)'].replace({'Unknown':0})
clean_df.columns
# Out:
# Index(['CaseID', 'City', 'State', 'Latitude', 'Longitude',
#        'Number of Victim Fatalities', 'Number of Victims Injured',
#        'Total Number of Victims', 'Date', 'Shooter Age(s)', 'Shooter Sex',
#        'Shooter Race', 'Type of Gun - General', 'Total Number of Guns',
#        'Shooter's Cause of Death', 'Place Type',
#        'Relationship to Incident Location', 'Targeted Victim/s - General',
#        'Possible Motive - General', 'History of Mental Illness - General',
#        'Military Experience'],
#       dtype='object')

# %%
# clean_df.loc[clean_df['Shooter Age(s)'] == 'Unknown', 'Shooter Age(s)'] = 0
clean_df = 

clean_df.loc[clean_df['Total Number of Guns'] == 'Unknown', 'Total Number of Guns'] = 0

clean_df
# Out:
# /Users/saheedosoba/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#      CaseID         City      State   Latitude   Longitude  \
# 0       1.0       Austin      Texas  30.198887  -97.844159
# 1       2.0         Mesa    Arizona  33.422687 -111.816320
# 2       3.0  New Orleans  Louisiana  30.068724  -89.931474
# 3       4.0      Chicago   Illinois  41.839280  -87.688181
# 4       5.0        Olean   New York  42.081854  -78.432139
# ..      ...          ...        ...        ...         ...
# 302   312.0  Brooksville    Alabama  34.162040  -86.475543
# 303   313.0    Baltimore   Maryland  39.290385  -76.612189
# ...

# %%
clean_df.rename(columns = {'CaseID':'case_id','City':'city', 'State':'state', 'Latitude':'latitude', 'Longitude':'longitude',
       'Number of Victim Fatalities':'number_of_victim_fatalities',
       'Number of Victims Injured': 'number_of_victims_injured', 'Total Number of Victims':'total_number_of_victims',
       'Date':'date',
       'Shooter Age(s)':'shooter_age(s)', 'Shooter Sex':'shooter_sex', 'Shooter Race':'shooter_race',
       'Type of Gun - General':'type_of_gun','Total Number of Guns':'total_number_of_guns',"Shooter's Cause of Death":'shooter_cause_of_death',
       'Place Type': 'place_type', 'Relationship to Incident Location':'relationship_to_incident_location',
       'Targeted Victim/s - General':'targeted_victims','Possible Motive - General':'possible_motive',
       'History of Mental Illness - General':'history_of_mental_illness', 'Military Experience':'military_experience'}, inplace = True)
# Out:
# /Users/saheedosoba/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
clean_df['date'] = pd.to_datetime(clean_df['date'])
clean_df['total_number_of_guns'] = pd.to_numeric(clean_df['total_number_of_guns'])
# Out:
# /var/folders/df/2jw1cn_d69j23pvjc1whb2ym0000gn/T/ipykernel_68384/2794638423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['date'] = pd.to_datetime(clean_df['date'])
# /var/folders/df/2jw1cn_d69j23pvjc1whb2ym0000gn/T/ipykernel_68384/2794638423.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['total_number_of_guns'] = pd.to_numeric(clean_df['total_number_of_guns'])

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307 entries, 0 to 306
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CaseID                             307 non-null    float64
#  1   city                               307 non-null    object
#  2   state                              307 non-null    object
#  3   latitude                           307 non-null    float64
#  4   longitude                          307 non-null    float64
#  5   number_of_victim_fatalities        307 non-null    float64
#  6   number_of_victims_injured          307 non-null    float64
#  7   total_number_of_victims            307 non-null    float64
#  8   date                               307 non-null    datetime64[ns]
#  9   shooter_age(s)                     307 non-null    object
#  10  shooter_sex                        307 non-null    object
# ...

# %%
clean_df
# Out:
#      CaseID         city      state   latitude   longitude  \
# 0       1.0       Austin      Texas  30.198887  -97.844159
# 1       2.0         Mesa    Arizona  33.422687 -111.816320
# 2       3.0  New Orleans  Louisiana  30.068724  -89.931474
# 3       4.0      Chicago   Illinois  41.839280  -87.688181
# 4       5.0        Olean   New York  42.081854  -78.432139
# ..      ...          ...        ...        ...         ...
# 302   312.0  Brooksville    Alabama  34.162040  -86.475543
# 303   313.0    Baltimore   Maryland  39.290385  -76.612189
# 304   314.0      Halifax   Virginia  36.765971  -78.928344
# 305   315.0  Forestville   Maryland  38.845113  -76.874972
# 306   316.0     Ferguson   Missouri  38.744217  -90.305391
#
#      number_of_victim_fatalities  number_of_victims_injured  \
# 0                           16.0                       32.0
# 1                            5.0                        1.0
# 2                            9.0                       13.0
# ...

# %%
clean_df.to_csv('Data/revised_cleanDF.csv', index = False)
